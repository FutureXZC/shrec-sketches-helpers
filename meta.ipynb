# %%
import os
import numpy as np
import pandas as pd

base = 'SHREC14'
data_dir = 'data'

# %%
def get_df_sketches(data_dir, sk_path):
    split = []
    cat = []
    paths = []
    ids = []
    for root, _, files in os.walk(os.path.join(data_dir, sk_path)):
        for f in files:
            if f[-3:] == 'png':
                split.append(root.split(os.path.sep)[-1])
                cat.append(root.split(os.path.sep)[-2])
                ids.append(os.path.splitext(f)[0])
                paths.append(os.path.join(sk_path, cat[-1], split[-1], f))

    df = pd.DataFrame(data={'cat': cat, 'split': split, 'id': ids},
                      index=paths)
    return df

# %%
# 获取草图的标签
sk_path = os.path.join(base, 'SHREC14LSSTB_SKETCHES', 'SHREC14LSSTB_SKETCHES')
df_sk = get_df_sketches(data_dir, sk_path)
print('sk_path: ', sk_path)
print('df_sk: ', df_sk)
print('shape: ', df_sk.shape)
# print('df_sk.loc[0]: ', df_sk.loc['cat'])
# Out:
# sk_path:  SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKETCHES
# df_sk:                                                              cat  split     id
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...     airplane   test     14
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...     airplane   test     19
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...     airplane   test     23
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...     airplane   test     24
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...     airplane   test     25
# ...                                                         ...    ...    ...
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...  wrist_watch  train  19911
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...  wrist_watch  train  19913
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...  wrist_watch  train  19916
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...  wrist_watch  train  19918
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...  wrist_watch  train  19919
#
# [13680 rows x 3 columns]
# shape:  (13680, 3)

# %%
def get_df_models(data_dir, cad_anno, cad_path):
    # read meta file
    fpath = os.path.join(data_dir, cad_anno)

    with open(fpath, 'r') as f:
        content = f.readlines()

    labels = {}
    current_cat = ''
    for line in content[3:]:
        line = line.strip('\r\n')
        line = line.strip('\t')
        line = line.strip()
        if len(line.split()) == 3:
            current_cat = line.split()[0]
        elif line != '':
            labels[line] = current_cat

    # read model folder
    cat = []
    ids = []
    paths = []
    for root, _, files in os.walk(os.path.join(data_dir, cad_path)):
        for f in files:
            if f[-3:] == 'off':
                ids.append(os.path.splitext(f)[0])
                cat.append(labels[ids[-1][1:]])
                paths.append(os.path.join(cad_path, f))

    df = pd.DataFrame(data={'cat': cat, 'id': ids},
                      index=paths)
    return df

# %%
# 获取3d模型的标签
# get cad labels
cad_path = os.path.join(base, 'SHREC14LSSTB_TARGET_MODELS')
eval_path = os.path.join(base, 'SHREC14_Sketch_Evaluation_CVIU')
cad_anno = os.path.join(eval_path, 'SHREC14_SBR_Model.cla')
print('cad_path: ', cad_path)
print('cad_anno: ', cad_anno)
print('eval_path: ', eval_path)
# get cad labels
df_cad = get_df_models(data_dir, cad_anno, cad_path)
print('df_cad: ', df_cad)
# Out:
# cad_path:  SHREC14\SHREC14LSSTB_TARGET_MODELS
# cad_anno:  SHREC14\SHREC14_Sketch_Evaluation_CVIU\SHREC14_SBR_Model.cla
# eval_path:  SHREC14\SHREC14_Sketch_Evaluation_CVIU
# df_cad:                                                        cat       id
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000001.off  bookshelf  M000001
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000002.off      table  M000002
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000003.off   airplane  M000003
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000004.off      train  M000004
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000005.off    bicycle  M000005
# ...                                                   ...      ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008983.off      chair  M008983
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008984.off    bicycle  M008984
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008985.off      table  M008985
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008986.off      sword  M008986
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008987.off      horse  M008987
#
# [8987 rows x 2 columns]

# %%
save_dir = os.path.join('labels', base)
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# 将dataframe数据存储到.hdf5文件内，便于以后读取
# 读取：pd.read_hdf(文件名, key)
df_sk.to_hdf(os.path.join(save_dir, 'sk_orig.hdf5'), 'sk')
df_cad.to_hdf(os.path.join(save_dir, 'cad_orig.hdf5'), 'cad')
print(os.path.join(save_dir, 'sk_orig.hdf5'))
print(os.path.join(save_dir, 'cad_orig.hdf5'))

# 把模型文件的路径存下来
with open(os.path.join(save_dir, 'cad.txt'), 'w') as f:
    for item in df_cad.index:
        f.write('%s\n' % item)
# Out:
# labels\SHREC14\sk_orig.hdf5
# labels\SHREC14\cad_orig.hdf5

# %%
def split_models(df_sk, df_cad):
    # 对3d模型的标签去重并排序，同时记录每个类别下的样本数量
    # vv：去重后的类别标签
    # cc：每个类别含有的样本数量
    vv, cc = np.unique(df_cad['cat'], return_counts=True)
    print('vv: ', vv)
    print('cc: ', cc)

    # 3d模型数量较少，许多类别下仅有少数样本，不利于学习，故应去除
    # 仅取出样本数量大于50的类别来使用
    coi = vv[cc > 50]
    n_coi = cc[cc > 50]
    print('coi: ', coi)
    print('n_coi: ', n_coi)
    print(df_sk['cat'])

    # 根据前面筛选的下标来取数据
    new_df_sk = df_sk.loc[df_sk['cat'].isin(coi)].copy()
    new_df_cad = df_cad.loc[df_cad['cat'].isin(coi)].copy()
    # print('new_df_sk: ', new_df_sk)
    print('new_df_cad(before split): ', new_df_cad)

    # randomly split instances
    np.random.seed(1234)
    # 先把所有的3d模型的划分标记为训练集，然后随机选取每个类20%的样本作为测试集
    new_df_cad.loc[:, 'split'] = 'train'
    for c, n in zip(coi, n_coi):
        to_select = int(np.floor(n * 0.2))
        subset = new_df_cad.loc[new_df_cad['cat'] == c, 'id']
        print('subset lebel: ', c, ': ', subset)
        # replace：True表示可以取相同数字，False表示不可以取相同数字
        id_to_select = np.random.choice(subset, size=to_select, replace=False)
        new_df_cad.loc[new_df_cad['id'].isin(id_to_select), 'split'] = 'test'
    print('------------------------------------')
    print('new_df_sk(after split): ')
    print(new_df_sk)
    print('------------------------------------')
    print('new_df_cad(after split): ')
    print(new_df_cad)

    return new_df_sk, new_df_cad

# %%
# split between train and test cad models
# following Qi et al BMVC 2018
new_df_sk, new_df_cad = split_models(df_sk, df_cad)

# 把划分好的数据集标签信息存储到labels\PART-SHREC14
save_dir = os.path.join('labels', 'PART-' + base)
print('save_dir: ', save_dir)
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

new_df_sk.to_hdf(os.path.join(save_dir, 'sk_orig.hdf5'), 'sk')
new_df_cad.to_hdf(os.path.join(save_dir, 'cad_orig.hdf5'), 'cad')
# Out:
# vv:  ['airplane' 'alarm_clock' 'ant' 'apple' 'armchair' 'ashtray' 'axe'
#  'banana' 'barn' 'baseball_bat' 'basket' 'bathtub' 'bear_animal' 'bed'
#  'bee' 'beer_mug' 'bench' 'bicycle' 'blimp' 'book' 'bookshelf' 'bowl'
#  'brain' 'bread' 'bridge' 'bus' 'bush' 'butterfly' 'cabinet' 'cake'
#  'camel' 'camera' 'candle' 'cannon' 'car_sedan' 'castle' 'cell_phone'
#  'chair' 'chandelier' 'church' 'cigarette' 'computer_monitor' 'couch'
#  'cow' 'crab' 'crocodile' 'cup' 'diamond' 'dog' 'dolphin' 'door'
#  'door_handle' 'dragon' 'duck' 'ear' 'elephant' 'eyeglasses' 'face' 'fan'
#  'fire_hydrant' 'fish' 'floor_lamp' 'flower_with_stem' 'flying_bird'
#  'flying_saucer' 'fork' 'frog' 'giraffe' 'grapes' 'guitar' 'hammer' 'hand'
#  'hat' 'head' 'helicopter' 'helmet' 'horse' 'hot_air_balloon' 'hourglass'
#  'house' 'human_skeleton' 'ice_cream_cone' 'kangaroo' 'key' 'keyboard'
#  'knife' 'ladder' 'laptop' 'leaf' 'lightbulb' 'lighter' 'lion' 'mailbox'
#  'microphone' 'microscope' 'monkey' 'motorbike' 'mug' 'mushroom' 'octopus'
#  'owl' 'palm_tree' 'parking_meter' 'parrot' 'pear' 'pen' 'penguin'
#  'person_sitting' 'person_walking' 'piano' 'pickup_truck' 'pig'
#  'pipe_for_smoking' 'potted_plant' 'pumpkin' 'rabbit' 'race_car' 'rifle'
#  'sailboat' 'satellite' 'satellite_dish' 'scissors' 'scorpion'
#  'screwdriver' 'sea_turtle' 'seagull' 'shark' 'sheep' 'ship' 'shoe'
#  'shovel' 'skateboard' 'skull' 'skyscraper' 'snake' 'snowman'
#  'space_shuttle' 'spider' 'spoon' 'standing_bird' 'stapler' 'submarine'
#  'suitcase' 'suv' 'sword' 'syringe' 'table' 'tablelamp' 'teacup' 'teapot'
#  'teddy_bear' 'telephone' 'tennis_racket' 'tent' 'tire' 'toilet' 'tooth'
#  'traffic_light' 'train' 'tree' 'truck' 'tv' 'umbrella' 'van' 'vase'
#  'violin' 'wheel' 'windmill' 'wine_bottle' 'wineglass' 'wrist_watch']
# cc:  [314   2  57  13 333   6  24  11   7   8   1  31  12 169  11  20  53 102
#   15  39 202   6  12   2  20 128  18  18 208   1   5   7  14  20  51  25
#  170 632   2  27   8  45 131  22  30   4  35   2  38  43  98   4  15   7
#    3   5  92  98  37   1 204 108  74  94  31   7   5   1   5 185  22  93
#   31 189 162  30  96  10  23 104   5  12   4   7 142 152  17 188  18  20
#    4   1  18  10  12   4 172   8   9  25   1  13   1   1  11  27   1  10
#    9 137  14  13   5 169   5   8  60  47  19  53  14   3   4  12  13   3
#   34   3 106  21  19  10  24  25  34   6  29  60  78  83   3  46  10  17
#  245   5 601  90  17   4  20  61   1   9   5  27   4   7 175 224  52  32
#   14   1  78  59 106   4  34  12  23]
# coi:  ['airplane' 'ant' 'armchair' 'bed' 'bench' 'bicycle' 'bookshelf' 'bus'
#  'cabinet' 'car_sedan' 'cell_phone' 'chair' 'couch' 'door' 'eyeglasses'
#  'face' 'fish' 'floor_lamp' 'flower_with_stem' 'flying_bird' 'guitar'
#  'hand' 'head' 'helicopter' 'horse' 'house' 'keyboard' 'knife' 'laptop'
#  'motorbike' 'piano' 'potted_plant' 'race_car' 'satellite' 'ship' 'spider'
#  'spoon' 'standing_bird' 'sword' 'table' 'tablelamp' 'telephone' 'train'
#  'tree' 'truck' 'vase' 'violin' 'wheel']
# n_coi:  [314  57 333 169  53 102 202 128 208  51 170 632 131  98  92  98 204 108
#   74  94 185  93 189 162  96 104 142 152 188 172 137 169  60  53 106  60
#   78  83 245 601  90  61 175 224  52  78  59 106]
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKETCHES\airplane\test\14.png              airplane
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKETCHES\airplane\test\19.png              airplane
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKETCHES\airplane\test\23.png              airplane
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKETCHES\airplane\test\24.png              airplane
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKETCHES\airplane\test\25.png              airplane
#                                                                                       ...
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKETCHES\wrist_watch\train\19911.png    wrist_watch
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKETCHES\wrist_watch\train\19913.png    wrist_watch
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKETCHES\wrist_watch\train\19916.png    wrist_watch
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKETCHES\wrist_watch\train\19918.png    wrist_watch
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKETCHES\wrist_watch\train\19919.png    wrist_watch
# Name: cat, Length: 13680, dtype: object
# new_df_cad(before split):                                                        cat       id
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000001.off  bookshelf  M000001
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000002.off      table  M000002
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000003.off   airplane  M000003
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000004.off      train  M000004
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000005.off    bicycle  M000005
# ...                                                   ...      ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008983.off      chair  M008983
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008984.off    bicycle  M008984
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008985.off      table  M008985
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008986.off      sword  M008986
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008987.off      horse  M008987
#
# [7238 rows x 2 columns]
# subset lebel:  airplane :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000003.off    M000003
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000017.off    M000017
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000019.off    M000019
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000021.off    M000021
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000027.off    M000027
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008916.off    M008916
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008918.off    M008918
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008930.off    M008930
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008950.off    M008950
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008974.off    M008974
# Name: id, Length: 314, dtype: object
# subset lebel:  ant :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000061.off    M000061
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000277.off    M000277
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000330.off    M000330
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000346.off    M000346
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001042.off    M001042
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001152.off    M001152
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001201.off    M001201
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001337.off    M001337
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001338.off    M001338
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001414.off    M001414
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001454.off    M001454
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001508.off    M001508
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001589.off    M001589
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001714.off    M001714
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001842.off    M001842
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001900.off    M001900
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001978.off    M001978
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001991.off    M001991
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002056.off    M002056
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002093.off    M002093
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002837.off    M002837
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003088.off    M003088
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003147.off    M003147
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003409.off    M003409
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003572.off    M003572
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003853.off    M003853
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004268.off    M004268
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004348.off    M004348
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004453.off    M004453
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004563.off    M004563
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004591.off    M004591
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005196.off    M005196
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005250.off    M005250
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005307.off    M005307
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005598.off    M005598
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005636.off    M005636
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005692.off    M005692
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006097.off    M006097
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006240.off    M006240
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006334.off    M006334
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006567.off    M006567
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006744.off    M006744
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007029.off    M007029
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007144.off    M007144
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007716.off    M007716
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008075.off    M008075
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008179.off    M008179
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008244.off    M008244
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008248.off    M008248
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008270.off    M008270
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008335.off    M008335
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008384.off    M008384
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008425.off    M008425
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008483.off    M008483
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008774.off    M008774
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008878.off    M008878
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008914.off    M008914
# Name: id, dtype: object
# subset lebel:  armchair :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000022.off    M000022
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000033.off    M000033
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000120.off    M000120
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000158.off    M000158
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000178.off    M000178
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008892.off    M008892
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008911.off    M008911
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008920.off    M008920
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008922.off    M008922
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008942.off    M008942
# Name: id, Length: 333, dtype: object
# subset lebel:  bed :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000012.off    M000012
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000155.off    M000155
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000179.off    M000179
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000230.off    M000230
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000374.off    M000374
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008657.off    M008657
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008661.off    M008661
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008699.off    M008699
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008854.off    M008854
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008894.off    M008894
# Name: id, Length: 169, dtype: object
# subset lebel:  bench :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000094.off    M000094
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000648.off    M000648
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000813.off    M000813
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000890.off    M000890
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000898.off    M000898
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000975.off    M000975
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000976.off    M000976
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001493.off    M001493
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001495.off    M001495
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001506.off    M001506
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001669.off    M001669
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001686.off    M001686
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001692.off    M001692
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002207.off    M002207
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002224.off    M002224
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002374.off    M002374
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003009.off    M003009
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003157.off    M003157
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003620.off    M003620
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004037.off    M004037
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004609.off    M004609
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005031.off    M005031
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005719.off    M005719
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005720.off    M005720
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005840.off    M005840
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005978.off    M005978
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006000.off    M006000
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006106.off    M006106
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006144.off    M006144
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006732.off    M006732
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006772.off    M006772
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006828.off    M006828
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007014.off    M007014
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007056.off    M007056
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007288.off    M007288
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007383.off    M007383
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007476.off    M007476
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007564.off    M007564
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007593.off    M007593
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007745.off    M007745
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007831.off    M007831
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007861.off    M007861
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007961.off    M007961
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008056.off    M008056
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008215.off    M008215
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008330.off    M008330
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008352.off    M008352
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008573.off    M008573
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008603.off    M008603
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008643.off    M008643
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008675.off    M008675
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008718.off    M008718
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008947.off    M008947
# Name: id, dtype: object
# subset lebel:  bicycle :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000005.off    M000005
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000052.off    M000052
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000075.off    M000075
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000100.off    M000100
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000161.off    M000161
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008333.off    M008333
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008604.off    M008604
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008773.off    M008773
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008973.off    M008973
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008984.off    M008984
# Name: id, Length: 102, dtype: object
# subset lebel:  bookshelf :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000001.off    M000001
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000068.off    M000068
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000089.off    M000089
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000096.off    M000096
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000117.off    M000117
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008738.off    M008738
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008744.off    M008744
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008849.off    M008849
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008865.off    M008865
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008890.off    M008890
# Name: id, Length: 202, dtype: object
# subset lebel:  bus :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000056.off    M000056
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000226.off    M000226
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000266.off    M000266
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000270.off    M000270
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000310.off    M000310
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008912.off    M008912
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008913.off    M008913
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008928.off    M008928
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008962.off    M008962
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008981.off    M008981
# Name: id, Length: 128, dtype: object
# subset lebel:  cabinet :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000051.off    M000051
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000105.off    M000105
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000141.off    M000141
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000164.off    M000164
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000321.off    M000321
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008701.off    M008701
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008734.off    M008734
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008756.off    M008756
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008938.off    M008938
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008969.off    M008969
# Name: id, Length: 208, dtype: object
# subset lebel:  car_sedan :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000413.off    M000413
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000419.off    M000419
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000478.off    M000478
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000511.off    M000511
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000564.off    M000564
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000610.off    M000610
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001122.off    M001122
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001324.off    M001324
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001329.off    M001329
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001384.off    M001384
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001521.off    M001521
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001593.off    M001593
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001604.off    M001604
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001635.off    M001635
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002037.off    M002037
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002188.off    M002188
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002427.off    M002427
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002508.off    M002508
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002511.off    M002511
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003672.off    M003672
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003897.off    M003897
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004156.off    M004156
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004718.off    M004718
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004745.off    M004745
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004869.off    M004869
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005225.off    M005225
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005247.off    M005247
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005524.off    M005524
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005646.off    M005646
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005792.off    M005792
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005851.off    M005851
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005853.off    M005853
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005971.off    M005971
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006089.off    M006089
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006220.off    M006220
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006398.off    M006398
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006564.off    M006564
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006829.off    M006829
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007100.off    M007100
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007172.off    M007172
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007184.off    M007184
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007212.off    M007212
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007851.off    M007851
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007957.off    M007957
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008178.off    M008178
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008273.off    M008273
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008311.off    M008311
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008313.off    M008313
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008720.off    M008720
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008805.off    M008805
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008859.off    M008859
# Name: id, dtype: object
# subset lebel:  cell_phone :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000060.off    M000060
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000074.off    M000074
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000076.off    M000076
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000098.off    M000098
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000132.off    M000132
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008481.off    M008481
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008504.off    M008504
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008505.off    M008505
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008811.off    M008811
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008833.off    M008833
# Name: id, Length: 170, dtype: object
# subset lebel:  chair :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000024.off    M000024
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000050.off    M000050
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000069.off    M000069
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000071.off    M000071
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000077.off    M000077
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008939.off    M008939
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008944.off    M008944
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008971.off    M008971
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008980.off    M008980
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008983.off    M008983
# Name: id, Length: 632, dtype: object
# subset lebel:  couch :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000006.off    M000006
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000059.off    M000059
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000082.off    M000082
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000106.off    M000106
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000115.off    M000115
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008623.off    M008623
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008765.off    M008765
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008797.off    M008797
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008842.off    M008842
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008889.off    M008889
# Name: id, Length: 131, dtype: object
# subset lebel:  door :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000121.off    M000121
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000194.off    M000194
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000556.off    M000556
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000607.off    M000607
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000613.off    M000613
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008250.off    M008250
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008593.off    M008593
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008664.off    M008664
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008683.off    M008683
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008694.off    M008694
# Name: id, Length: 98, dtype: object
# subset lebel:  eyeglasses :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000018.off    M000018
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000057.off    M000057
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000085.off    M000085
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000114.off    M000114
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000168.off    M000168
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008458.off    M008458
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008544.off    M008544
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008560.off    M008560
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008695.off    M008695
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008869.off    M008869
# Name: id, Length: 92, dtype: object
# subset lebel:  face :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000009.off    M000009
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000397.off    M000397
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000460.off    M000460
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000576.off    M000576
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000625.off    M000625
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008474.off    M008474
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008522.off    M008522
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008802.off    M008802
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008821.off    M008821
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008879.off    M008879
# Name: id, Length: 98, dtype: object
# subset lebel:  fish :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000090.off    M000090
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000112.off    M000112
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000127.off    M000127
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000148.off    M000148
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000154.off    M000154
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008747.off    M008747
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008852.off    M008852
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008883.off    M008883
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008919.off    M008919
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008933.off    M008933
# Name: id, Length: 204, dtype: object
# subset lebel:  floor_lamp :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000073.off    M000073
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000204.off    M000204
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000319.off    M000319
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000412.off    M000412
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000423.off    M000423
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008488.off    M008488
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008501.off    M008501
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008551.off    M008551
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008558.off    M008558
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008768.off    M008768
# Name: id, Length: 108, dtype: object
# subset lebel:  flower_with_stem :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000466.off    M000466
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000485.off    M000485
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000546.off    M000546
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000647.off    M000647
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000657.off    M000657
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008749.off    M008749
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008770.off    M008770
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008787.off    M008787
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008816.off    M008816
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008867.off    M008867
# Name: id, Length: 74, dtype: object
# subset lebel:  flying_bird :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000268.off    M000268
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000375.off    M000375
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000406.off    M000406
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000633.off    M000633
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000830.off    M000830
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008686.off    M008686
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008693.off    M008693
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008871.off    M008871
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008953.off    M008953
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008964.off    M008964
# Name: id, Length: 94, dtype: object
# subset lebel:  guitar :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000028.off    M000028
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000044.off    M000044
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000169.off    M000169
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000177.off    M000177
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000185.off    M000185
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008814.off    M008814
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008815.off    M008815
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008853.off    M008853
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008855.off    M008855
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008979.off    M008979
# Name: id, Length: 185, dtype: object
# subset lebel:  hand :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000221.off    M000221
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000245.off    M000245
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000306.off    M000306
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000445.off    M000445
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000650.off    M000650
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008276.off    M008276
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008301.off    M008301
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008702.off    M008702
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008779.off    M008779
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008898.off    M008898
# Name: id, Length: 93, dtype: object
# subset lebel:  head :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000038.off    M000038
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000055.off    M000055
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000086.off    M000086
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000099.off    M000099
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000126.off    M000126
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008848.off    M008848
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008882.off    M008882
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008908.off    M008908
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008926.off    M008926
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008956.off    M008956
# Name: id, Length: 189, dtype: object
# subset lebel:  helicopter :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000054.off    M000054
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000078.off    M000078
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000111.off    M000111
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000138.off    M000138
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000176.off    M000176
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008618.off    M008618
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008674.off    M008674
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008782.off    M008782
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008783.off    M008783
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008790.off    M008790
# Name: id, Length: 162, dtype: object
# subset lebel:  horse :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000049.off    M000049
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000197.off    M000197
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000234.off    M000234
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000376.off    M000376
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000403.off    M000403
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008706.off    M008706
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008745.off    M008745
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008825.off    M008825
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008850.off    M008850
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008987.off    M008987
# Name: id, Length: 96, dtype: object
# subset lebel:  house :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000097.off    M000097
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000130.off    M000130
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000190.off    M000190
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000220.off    M000220
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000246.off    M000246
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008662.off    M008662
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008725.off    M008725
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008740.off    M008740
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008831.off    M008831
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008949.off    M008949
# Name: id, Length: 104, dtype: object
# subset lebel:  keyboard :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000211.off    M000211
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000255.off    M000255
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000282.off    M000282
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000335.off    M000335
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000565.off    M000565
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008663.off    M008663
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008669.off    M008669
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008856.off    M008856
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008876.off    M008876
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008961.off    M008961
# Name: id, Length: 142, dtype: object
# subset lebel:  knife :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000065.off    M000065
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000104.off    M000104
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000119.off    M000119
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000133.off    M000133
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000191.off    M000191
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008500.off    M008500
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008507.off    M008507
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008592.off    M008592
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008794.off    M008794
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008982.off    M008982
# Name: id, Length: 152, dtype: object
# subset lebel:  laptop :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000030.off    M000030
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000037.off    M000037
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000039.off    M000039
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000047.off    M000047
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000195.off    M000195
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008739.off    M008739
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008844.off    M008844
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008861.off    M008861
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008862.off    M008862
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008896.off    M008896
# Name: id, Length: 188, dtype: object
# subset lebel:  motorbike :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000276.off    M000276
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000297.off    M000297
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000339.off    M000339
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000347.off    M000347
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000358.off    M000358
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008789.off    M008789
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008796.off    M008796
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008826.off    M008826
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008901.off    M008901
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008915.off    M008915
# Name: id, Length: 172, dtype: object
# subset lebel:  piano :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000265.off    M000265
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000316.off    M000316
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000353.off    M000353
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000382.off    M000382
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000499.off    M000499
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008820.off    M008820
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008824.off    M008824
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008847.off    M008847
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008893.off    M008893
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008978.off    M008978
# Name: id, Length: 137, dtype: object
# subset lebel:  potted_plant :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000020.off    M000020
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000083.off    M000083
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000109.off    M000109
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000189.off    M000189
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000285.off    M000285
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008801.off    M008801
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008858.off    M008858
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008880.off    M008880
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008957.off    M008957
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008960.off    M008960
# Name: id, Length: 169, dtype: object
# subset lebel:  race_car :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000113.off    M000113
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000123.off    M000123
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000550.off    M000550
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000785.off    M000785
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000827.off    M000827
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000970.off    M000970
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001210.off    M001210
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001284.off    M001284
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001341.off    M001341
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001380.off    M001380
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001396.off    M001396
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001402.off    M001402
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001836.off    M001836
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002042.off    M002042
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002144.off    M002144
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002312.off    M002312
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002556.off    M002556
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002670.off    M002670
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003029.off    M003029
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003046.off    M003046
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003059.off    M003059
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003453.off    M003453
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003530.off    M003530
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003585.off    M003585
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003645.off    M003645
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003739.off    M003739
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003918.off    M003918
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004377.off    M004377
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004435.off    M004435
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004496.off    M004496
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005082.off    M005082
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005342.off    M005342
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005472.off    M005472
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005607.off    M005607
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005776.off    M005776
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005899.off    M005899
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005940.off    M005940
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006065.off    M006065
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006184.off    M006184
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006325.off    M006325
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006381.off    M006381
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006487.off    M006487
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006678.off    M006678
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006764.off    M006764
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006843.off    M006843
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006996.off    M006996
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007318.off    M007318
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007347.off    M007347
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007536.off    M007536
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007763.off    M007763
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007863.off    M007863
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007896.off    M007896
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007899.off    M007899
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007969.off    M007969
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008082.off    M008082
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008138.off    M008138
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008378.off    M008378
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008619.off    M008619
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008902.off    M008902
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008907.off    M008907
# Name: id, dtype: object
# subset lebel:  satellite :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000026.off    M000026
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000163.off    M000163
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000199.off    M000199
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000218.off    M000218
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000495.off    M000495
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000793.off    M000793
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000893.off    M000893
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001087.off    M001087
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001180.off    M001180
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001298.off    M001298
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001388.off    M001388
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001664.off    M001664
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002117.off    M002117
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002301.off    M002301
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002314.off    M002314
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002512.off    M002512
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002771.off    M002771
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002945.off    M002945
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002987.off    M002987
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002992.off    M002992
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003130.off    M003130
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003186.off    M003186
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003360.off    M003360
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003379.off    M003379
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003451.off    M003451
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003549.off    M003549
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003555.off    M003555
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004757.off    M004757
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004835.off    M004835
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005103.off    M005103
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005199.off    M005199
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005777.off    M005777
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006218.off    M006218
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006222.off    M006222
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006626.off    M006626
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006932.off    M006932
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007089.off    M007089
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007095.off    M007095
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007123.off    M007123
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007290.off    M007290
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007382.off    M007382
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007449.off    M007449
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007876.off    M007876
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007929.off    M007929
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007937.off    M007937
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007955.off    M007955
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007989.off    M007989
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008021.off    M008021
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008091.off    M008091
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008374.off    M008374
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008620.off    M008620
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008925.off    M008925
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008966.off    M008966
# Name: id, dtype: object
# subset lebel:  ship :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000031.off    M000031
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000045.off    M000045
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000165.off    M000165
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000258.off    M000258
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000262.off    M000262
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008240.off    M008240
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008256.off    M008256
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008461.off    M008461
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008868.off    M008868
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008899.off    M008899
# Name: id, Length: 106, dtype: object
# subset lebel:  spider :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000072.off    M000072
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000110.off    M000110
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000124.off    M000124
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000263.off    M000263
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000638.off    M000638
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000642.off    M000642
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000685.off    M000685
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001061.off    M001061
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001326.off    M001326
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001335.off    M001335
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001718.off    M001718
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001956.off    M001956
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002018.off    M002018
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002420.off    M002420
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002513.off    M002513
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002624.off    M002624
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002757.off    M002757
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002762.off    M002762
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002940.off    M002940
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003033.off    M003033
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003214.off    M003214
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003270.off    M003270
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003332.off    M003332
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003389.off    M003389
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003514.off    M003514
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003653.off    M003653
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003913.off    M003913
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004105.off    M004105
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004355.off    M004355
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004371.off    M004371
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004800.off    M004800
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004935.off    M004935
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004952.off    M004952
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005005.off    M005005
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005050.off    M005050
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005391.off    M005391
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005628.off    M005628
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005736.off    M005736
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005888.off    M005888
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005921.off    M005921
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006015.off    M006015
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006100.off    M006100
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006120.off    M006120
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006252.off    M006252
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006303.off    M006303
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006335.off    M006335
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006396.off    M006396
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006553.off    M006553
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006975.off    M006975
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007196.off    M007196
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007262.off    M007262
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007463.off    M007463
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007592.off    M007592
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007601.off    M007601
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007944.off    M007944
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007967.off    M007967
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008272.off    M008272
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008284.off    M008284
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008309.off    M008309
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008875.off    M008875
# Name: id, dtype: object
# subset lebel:  spoon :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000011.off    M000011
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000041.off    M000041
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000048.off    M000048
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000338.off    M000338
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000590.off    M000590
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008634.off    M008634
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008659.off    M008659
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008691.off    M008691
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008798.off    M008798
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008822.off    M008822
# Name: id, Length: 78, dtype: object
# subset lebel:  standing_bird :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000043.off    M000043
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000131.off    M000131
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000181.off    M000181
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000280.off    M000280
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000571.off    M000571
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008609.off    M008609
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008645.off    M008645
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008671.off    M008671
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008709.off    M008709
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008886.off    M008886
# Name: id, Length: 83, dtype: object
# subset lebel:  sword :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000223.off    M000223
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000232.off    M000232
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000267.off    M000267
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000301.off    M000301
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000313.off    M000313
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008703.off    M008703
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008735.off    M008735
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008863.off    M008863
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008952.off    M008952
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008986.off    M008986
# Name: id, Length: 245, dtype: object
# subset lebel:  table :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000002.off    M000002
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000008.off    M000008
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000015.off    M000015
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000036.off    M000036
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000046.off    M000046
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008921.off    M008921
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008934.off    M008934
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008963.off    M008963
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008968.off    M008968
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008985.off    M008985
# Name: id, Length: 601, dtype: object
# subset lebel:  tablelamp :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000032.off    M000032
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000053.off    M000053
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000360.off    M000360
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000428.off    M000428
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000555.off    M000555
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008555.off    M008555
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008617.off    M008617
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008728.off    M008728
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008766.off    M008766
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008813.off    M008813
# Name: id, Length: 90, dtype: object
# subset lebel:  telephone :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000088.off    M000088
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000225.off    M000225
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000284.off    M000284
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000328.off    M000328
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000344.off    M000344
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008639.off    M008639
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008715.off    M008715
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008786.off    M008786
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008830.off    M008830
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008946.off    M008946
# Name: id, Length: 61, dtype: object
# subset lebel:  train :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000004.off    M000004
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000063.off    M000063
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000081.off    M000081
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000108.off    M000108
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000128.off    M000128
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008778.off    M008778
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008819.off    M008819
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008872.off    M008872
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008945.off    M008945
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008977.off    M008977
# Name: id, Length: 175, dtype: object
# subset lebel:  tree :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000007.off    M000007
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000058.off    M000058
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000091.off    M000091
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000401.off    M000401
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000409.off    M000409
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008707.off    M008707
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008750.off    M008750
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008857.off    M008857
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008906.off    M008906
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008954.off    M008954
# Name: id, Length: 224, dtype: object
# subset lebel:  truck :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000103.off    M000103
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000216.off    M000216
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000227.off    M000227
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000345.off    M000345
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000537.off    M000537
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001221.off    M001221
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001959.off    M001959
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002097.off    M002097
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002318.off    M002318
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002356.off    M002356
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002384.off    M002384
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002532.off    M002532
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002758.off    M002758
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002764.off    M002764
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002876.off    M002876
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003114.off    M003114
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003339.off    M003339
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003413.off    M003413
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003433.off    M003433
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003517.off    M003517
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003726.off    M003726
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003878.off    M003878
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004141.off    M004141
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004339.off    M004339
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004481.off    M004481
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004654.off    M004654
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004960.off    M004960
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005016.off    M005016
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005017.off    M005017
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005041.off    M005041
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005265.off    M005265
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005519.off    M005519
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005604.off    M005604
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005654.off    M005654
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005739.off    M005739
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005886.off    M005886
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006032.off    M006032
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006164.off    M006164
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006340.off    M006340
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006754.off    M006754
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006917.off    M006917
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007194.off    M007194
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007311.off    M007311
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007392.off    M007392
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007490.off    M007490
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007602.off    M007602
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007643.off    M007643
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007820.off    M007820
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007904.off    M007904
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007956.off    M007956
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008764.off    M008764
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008897.off    M008897
# Name: id, dtype: object
# subset lebel:  vase :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000084.off    M000084
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000193.off    M000193
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000744.off    M000744
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000774.off    M000774
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000922.off    M000922
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008294.off    M008294
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008492.off    M008492
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008599.off    M008599
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008736.off    M008736
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008881.off    M008881
# Name: id, Length: 78, dtype: object
# subset lebel:  violin :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000438.off    M000438
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000507.off    M000507
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000718.off    M000718
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000881.off    M000881
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001028.off    M001028
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001204.off    M001204
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001211.off    M001211
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001420.off    M001420
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001422.off    M001422
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001436.off    M001436
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001699.off    M001699
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001792.off    M001792
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M001907.off    M001907
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002086.off    M002086
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002366.off    M002366
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002468.off    M002468
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002559.off    M002559
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002797.off    M002797
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002801.off    M002801
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002821.off    M002821
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M002921.off    M002921
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003021.off    M003021
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003104.off    M003104
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003217.off    M003217
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003533.off    M003533
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003680.off    M003680
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003718.off    M003718
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003766.off    M003766
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003982.off    M003982
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M003998.off    M003998
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004086.off    M004086
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004232.off    M004232
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004237.off    M004237
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004245.off    M004245
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004304.off    M004304
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004729.off    M004729
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004825.off    M004825
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004881.off    M004881
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M004981.off    M004981
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005106.off    M005106
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005162.off    M005162
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005238.off    M005238
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005336.off    M005336
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005933.off    M005933
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M005977.off    M005977
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006070.off    M006070
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M006345.off    M006345
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007310.off    M007310
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007329.off    M007329
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007489.off    M007489
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007504.off    M007504
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007618.off    M007618
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007725.off    M007725
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M007939.off    M007939
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008004.off    M008004
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008641.off    M008641
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008793.off    M008793
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008873.off    M008873
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008937.off    M008937
# Name: id, dtype: object
# subset lebel:  wheel :  SHREC14\SHREC14LSSTB_TARGET_MODELS\M000034.off    M000034
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000170.off    M000170
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000292.off    M000292
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000340.off    M000340
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000356.off    M000356
#                                                    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008670.off    M008670
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008719.off    M008719
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008776.off    M008776
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008807.off    M008807
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008888.off    M008888
# Name: id, Length: 106, dtype: object
# ------------------------------------
# new_df_sk(after split):
#                                                          cat  split     id
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...  airplane   test     14
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...  airplane   test     19
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...  airplane   test     23
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...  airplane   test     24
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...  airplane   test     25
# ...                                                      ...    ...    ...
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...     wheel  train  19514
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...     wheel  train  19515
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...     wheel  train  19516
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...     wheel  train  19517
# SHREC14\SHREC14LSSTB_SKETCHES\SHREC14LSSTB_SKET...     wheel  train  19518
#
# [3840 rows x 3 columns]
# ------------------------------------
# new_df_cad(after split):
#                                                       cat       id  split
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000001.off  bookshelf  M000001  train
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000002.off      table  M000002   test
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000003.off   airplane  M000003  train
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000004.off      train  M000004  train
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M000005.off    bicycle  M000005  train
# ...                                                   ...      ...    ...
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008983.off      chair  M008983   test
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008984.off    bicycle  M008984   test
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008985.off      table  M008985  train
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008986.off      sword  M008986  train
# SHREC14\SHREC14LSSTB_TARGET_MODELS\M008987.off      horse  M008987   test
#
# [7238 rows x 3 columns]
# save_dir:  labels\PART-SHREC14
